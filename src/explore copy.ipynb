# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd

# Ver dónde estamos exactamente
print("📍 Directorio actual:", os.getcwd())

# Ver qué hay en el directorio actual
print("\n📁 Contenido del directorio actual:")
for item in os.listdir('.'):
    print(f" - {item}")

# Crear la estructura de carpetas desde cero
os.makedirs('/workspaces/machine-learning-python-template/data/raw', exist_ok=True)
os.makedirs('/workspaces/machine-learning-python-template/data/processed', exist_ok=True)

print("\n✅ Carpetas creadas en la ruta correcta")

# Descargar el archivo directamente
print("\n📥 Descargando datos...")
url = "https://breathecode.herokuapp.com/asset/internal-link?id=927&path=AB_NYC_2019.csv"
df = pd.read_csv(url)

# Guardar en la ruta correcta
file_path = '/workspaces/machine-learning-python-template/data/raw/AB_NYC_2019.csv'
df.to_csv(file_path, index=False)

print(f"✅ Archivo guardado en: {file_path}")
print(f"📊 Dimensiones del dataset: {df.shape}")
print(f"📝 Columnas: {list(df.columns)}")

# Mostrar primeras filas
print("\n🔍 Primeras 5 filas:")
df.head()
# Out:
# 📍 Directorio actual: /workspaces/machine-learning-python-template/src
#
# 📁 Contenido del directorio actual:
#  - utils.py
#  - explore.ipynb
#  - app.py
#
# ✅ Carpetas creadas en la ruta correcta
#
# 📥 Descargando datos...
# ✅ Archivo guardado en: /workspaces/machine-learning-python-template/data/raw/AB_NYC_2019.csv
# 📊 Dimensiones del dataset: (48895, 16)
# 📝 Columnas: ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']
#
# 🔍 Primeras 5 filas:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Usar la ruta absoluta que mencionaste
file_path = '/workspaces/machine-learning-python-template/data/raw/AB_NYC_2019.csv'

# Verificar si el archivo existe
if os.path.exists(file_path):
    print(f"✅ Archivo encontrado en: {file_path}")
    
    # Cargar datos
    df = pd.read_csv(file_path)
    
    print("=== ANÁLISIS INICIAL AIRBNB NYC ===")
    print(f"📊 Dimensiones: {df.shape}")
    print(f"📝 Número de columnas: {len(df.columns)}")
    
    print("\n=== INFORMACIÓN DEL DATASET ===")
    df.info()
    
    print("\n🔍 Primeras 5 filas:")
    df.head()
    
else:
    print(f"❌ Archivo NO encontrado en: {file_path}")
    print("\n📁 Buscando archivos en el proyecto...")
    
    # Buscar recursivamente el archivo
    for root, dirs, files in os.walk('/workspaces/machine-learning-python-template'):
        for file in files:
            if 'AB_NYC' in file or 'airbnb' in file.lower():
                print(f"📄 Encontrado: {os.path.join(root, file)}")
# Out:
# ✅ Archivo encontrado en: /workspaces/machine-learning-python-template/data/raw/AB_NYC_2019.csv
# === ANÁLISIS INICIAL AIRBNB NYC ===
# 📊 Dimensiones: (48895, 16)
# 📝 Número de columnas: 16
#
# === INFORMACIÓN DEL DATASET ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
# ...

# %%
print("=== ANÁLISIS DESCRIPTIVO ===")
print(df.describe())

print("\n=== VALORES NULOS ===")
print(df.isnull().sum().sort_values(ascending=False))

print("\n=== TIPOS DE HABITACIÓN ===")
print(df['room_type'].value_counts())

print("\n=== DISTRIBUCIÓN POR BARRIOS ===")
print(df['neighbourhood_group'].value_counts())
# Out:
# === ANÁLISIS DESCRIPTIVO ===
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
# Configurar el estilo de los gráficos
plt.style.use('default')
sns.set_palette("husl")

# 1. Distribución de precios
plt.figure(figsize=(15, 10))

plt.subplot(2, 3, 1)
sns.histplot(df['price'], bins=50)
plt.title('Distribución de Precios')
plt.xlabel('Precio ($)')
plt.xlim(0, 1000)  # Excluir outliers extremos

# 2. Tipos de habitación
plt.subplot(2, 3, 2)
df['room_type'].value_counts().plot(kind='bar')
plt.title('Tipos de Habitación')
plt.xticks(rotation=45)

# 3. Distribución por barrios
plt.subplot(2, 3, 3)
df['neighbourhood_group'].value_counts().plot(kind='bar')
plt.title('Propiedades por Barrio')
plt.xticks(rotation=45)

# 4. Precio promedio por barrio
plt.subplot(2, 3, 4)
sns.barplot(data=df, x='neighbourhood_group', y='price')
plt.title('Precio Promedio por Barrio')
plt.xticks(rotation=45)

# 5. Precio por tipo de habitación
plt.subplot(2, 3, 5)
sns.boxplot(data=df, x='room_type', y='price')
plt.title('Precio por Tipo de Habitación')
plt.xticks(rotation=45)
plt.ylim(0, 500)

# 6. Mapa de calor de correlaciones
plt.subplot(2, 3, 6)
numeric_cols = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365']
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', center=0)
plt.title('Correlaciones entre Variables')

plt.tight_layout()
plt.show()

# %%
# Primero, veamos QUÉ datos tenemos realmente
import pandas as pd

df = pd.read_csv('/workspaces/machine-learning-python-template/data/raw/AB_NYC_2019.csv')

print("=== INFORMACIÓN BÁSICA ===")
print(f"📊 Tenemos {len(df)} propiedades de Airbnb")
print(f"📝 Con {len(df.columns)} características cada una")

print("\n=== LISTA DE VARIABLES ===")
for i, col in enumerate(df.columns, 1):
    print(f"{i:2d}. {col}")

print("\n=== ¿QUÉ PODEMOS ANALIZAR? ===")
print("Basado en las variables, podríamos:")
print("1. 🏠 Estudiar precios y qué los afecta")
print("2. 📍 Analizar ubicaciones estratégicas")  
print("3. ⭐ Entender qué hace popular un Airbnb")
print("4. 🏙️ Comparar diferentes barrios de NYC")
# Out:
# === INFORMACIÓN BÁSICA ===
# 📊 Tenemos 48895 propiedades de Airbnb
# 📝 Con 16 características cada una
#
# === LISTA DE VARIABLES ===
#  1. id
#  2. name
#  3. host_id
#  4. host_name
#  5. neighbourhood_group
#  6. neighbourhood
#  7. latitude
#  8. longitude
#  9. room_type
# 10. price
# 11. minimum_nights
# 12. number_of_reviews
# 13. last_review
# 14. reviews_per_month
# 15. calculated_host_listings_count
# 16. availability_365
#
# === ¿QUÉ PODEMOS ANALIZAR? ===
# Basado en las variables, podríamos:
# 1. 🏠 Estudiar precios y qué los afecta
# 2. 📍 Analizar ubicaciones estratégicas
# 3. ⭐ Entender qué hace popular un Airbnb
# 4. 🏙️ Comparar diferentes barrios de NYC

# %%
# Veamos qué información nos da cada variable
print("=== ANÁLISIS DETALLADO DE VARIABLES ===")

variables_analisis = {
    'price': 'PRECIO - Variable objetivo natural',
    'neighbourhood_group': 'UBICACIÓN - Barrio (Manhattan, Brooklyn, etc.)', 
    'neighbourhood': 'UBICACIÓN - Vecindario específico',
    'room_type': 'CARACTERÍSTICA - Tipo de alojamiento',
    'minimum_nights': 'POLÍTICA - Estancia mínima',
    'number_of_reviews': 'POPULARIDAD - Cantidad de reseñas',
    'reviews_per_month': 'POPULARIDAD - Frecuencia de reseñas',
    'availability_365': 'DISPONIBILIDAD - Días disponibles/año',
    'calculated_host_listings_count': 'EXPERIENCIA - Propiedades del anfitrión'
}

for var, desc in variables_analisis.items():
    print(f"📍 {var:30} → {desc}")

print("\n" + "="*50)
print("🤔 PREGUNTAS QUE PODEMOS RESPONDER:")
print("1. ¿Qué factores influyen más en el PRECIO de un Airbnb?")
print("2. ¿En qué barrios se obtienen mejores precios?")
print("3. ¿Qué tipo de propiedades son más rentables?")
print("4. ¿La experiencia del anfitrión afecta el precio?")
# Out:
# === ANÁLISIS DETALLADO DE VARIABLES ===
# 📍 price                          → PRECIO - Variable objetivo natural
# 📍 neighbourhood_group            → UBICACIÓN - Barrio (Manhattan, Brooklyn, etc.)
# 📍 neighbourhood                  → UBICACIÓN - Vecindario específico
# 📍 room_type                      → CARACTERÍSTICA - Tipo de alojamiento
# 📍 minimum_nights                 → POLÍTICA - Estancia mínima
# 📍 number_of_reviews              → POPULARIDAD - Cantidad de reseñas
# 📍 reviews_per_month              → POPULARIDAD - Frecuencia de reseñas
# 📍 availability_365               → DISPONIBILIDAD - Días disponibles/año
# 📍 calculated_host_listings_count → EXPERIENCIA - Propiedades del anfitrión
#
# ...
# 🤔 PREGUNTAS QUE PODEMOS RESPONDER:
# 1. ¿Qué factores influyen más en el PRECIO de un Airbnb?
# 2. ¿En qué barrios se obtienen mejores precios?
# 3. ¿Qué tipo de propiedades son más rentables?
# 4. ¿La experiencia del anfitrión afecta el precio?

# %%
# Solo mostremos 3 filas para ver ejemplos concretos
print("=== EJEMPLOS REALES DE DATOS ===")
print("Estas son propiedades REALES de Airbnb:")
df_sample = df.head(3).copy()

for i, row in df_sample.iterrows():
    print(f"\n🏠 PROPIEDAD {i+1}:")
    print(f"   Nombre: {row['name']}")
    print(f"   Barrio: {row['neighbourhood_group']} - {row['neighbourhood']}")
    print(f"   Tipo: {row['room_type']}")
    print(f"   Precio: ${row['price']} por noche")
    print(f"   Mínimo noches: {row['minimum_nights']}")
    print(f"   Reviews: {row['number_of_reviews']}")
# Out:
# === EJEMPLOS REALES DE DATOS ===
# Estas son propiedades REALES de Airbnb:
#
# 🏠 PROPIEDAD 1:
#    Nombre: Clean & quiet apt home by the park
#    Barrio: Brooklyn - Kensington
#    Tipo: Private room
#    Precio: $149 por noche
#    Mínimo noches: 1
#    Reviews: 9
#
# 🏠 PROPIEDAD 2:
#    Nombre: Skylit Midtown Castle
#    Barrio: Manhattan - Midtown
#    Tipo: Entire home/apt
#    Precio: $225 por noche
#    Mínimo noches: 1
#    Reviews: 45
#
# 🏠 PROPIEDAD 3:
#    Nombre: THE VILLAGE OF HARLEM....NEW YORK !
#    Barrio: Manhattan - Harlem
#    Tipo: Private room
#    Precio: $150 por noche
#    Mínimo noches: 3
#    Reviews: 0
